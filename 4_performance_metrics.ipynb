# %%
import pandas as pd
import numpy as np

returns = pd.read_csv("india_equity_returns.csv", index_col="Date", parse_dates=True)
weights = pd.read_csv("portfolio_weights.csv")

equal_w = weights["Equal_Weight"].values
opt_w = weights["Optimized_Weight"].values

port_equal = returns @ equal_w
port_opt = returns @ opt_w

rf = 0.06 / 252

def sharpe(r):
    return (r.mean() - rf) / r.std()

def beta(r, m):
    return np.cov(r, m)[0,1] / np.var(m)

market = returns.mean(axis=1)

beta_eq = beta(port_equal, market)
beta_opt = beta(port_opt, market)

def treynor(r, b):
    return (r.mean() - rf) / b

def jensen(r, m, b):
    return r.mean() - (rf + b * (m.mean() - rf))

metrics = pd.DataFrame({
    "Portfolio": ["Equal Weight", "Optimized"],
    "Sharpe": [sharpe(port_equal), sharpe(port_opt)],
    "Beta": [beta_eq, beta_opt],
    "Treynor": [treynor(port_equal, beta_eq), treynor(port_opt, beta_opt)],
    "Jensen_Alpha": [
        jensen(port_equal, market, beta_eq),
        jensen(port_opt, market, beta_opt)
    ]
})

metrics.to_csv("portfolio_metrics.csv", index=False)

metrics
# Out:
#       Portfolio    Sharpe      Beta   Treynor  Jensen_Alpha
# 0  Equal Weight  0.335172  1.011905  0.016144     -0.000194
# 1     Optimized  0.430650  0.912249  0.024166      0.007142
